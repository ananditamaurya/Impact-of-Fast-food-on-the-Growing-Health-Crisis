# %%
import pandas as pd
import numpy as np

# %%
#Read all the data files related to population over the years
population2015 = pd.read_csv("ACSST1Y2015.S0103-Data.csv")
population2016 = pd.read_csv("ACSST1Y2016.S0103-Data.csv")
population2017 = pd.read_csv("ACSST1Y2017.S0103-Data.csv")
population2018 = pd.read_csv("ACSST1Y2018.S0103-Data.csv")
population2019 = pd.read_csv("ACSST1Y2019.S0103-Data.csv")
population2020 = pd.read_csv("ACSST1Y2020.S0103-Data.csv")

# %%
population2015.head()
# Out:
#         GEO_ID        NAME  S0103_C01_001E  S0103_C01_001EA S0103_C01_001M  \
# 0  0400000US01     Alabama       4858979.0              NaN          *****
# 1  0400000US02      Alaska        738432.0              NaN          *****
# 2  0400000US04     Arizona       6828065.0              NaN          *****
# 3  0400000US05    Arkansas       2978204.0              NaN          *****
# 4  0400000US06  California      39144818.0              NaN          *****
#
#   S0103_C01_001MA  S0103_C02_001E  S0103_C02_001M  S0103_C02_001MA  \
# 0           *****        761847.0          2695.0              NaN
# 1           *****         71008.0          1096.0              NaN
# 2           *****       1120004.0          1647.0              NaN
# 3           *****        478114.0          1779.0              NaN
# 4           *****       5189558.0          2790.0              NaN
#
#    S0103_C02_001EA  ...  S0103_C02_103MA  S0103_C01_104E  S0103_C01_104EA  \
# ...

# %%
p2015 = population2015[['NAME','S0103_C01_001E']]
p2015["2015"] = p2015["S0103_C01_001E"]
# Out:
# /var/folders/6t/m3brq_pj49jd39l2d8j6jp000000gn/T/ipykernel_79327/2932478772.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p2015["2015"] = p2015["S0103_C01_001E"]

# %%
p2015.head()
# Out:
#          NAME  S0103_C01_001E        2015
# 0     Alabama       4858979.0   4858979.0
# 1      Alaska        738432.0    738432.0
# 2     Arizona       6828065.0   6828065.0
# 3    Arkansas       2978204.0   2978204.0
# 4  California      39144818.0  39144818.0

# %%
p2015 = p2015.drop(['S0103_C01_001E'], axis=1)

# %%
#Population of all the states in the year 2015
p2015.head()
# Out:
#          NAME        2015
# 0     Alabama   4858979.0
# 1      Alaska    738432.0
# 2     Arizona   6828065.0
# 3    Arkansas   2978204.0
# 4  California  39144818.0

# %%
p2016 = population2016[['S0103_C01_001E']]
p2016["2016"] = p2016["S0103_C01_001E"]
# Out:
# /var/folders/6t/m3brq_pj49jd39l2d8j6jp000000gn/T/ipykernel_79327/4203691331.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p2016["2016"] = p2016["S0103_C01_001E"]

# %%
p2016 = p2016.drop(['S0103_C01_001E'], axis=1)

# %%
#Population of all the states in the year 2016
p2016.head()
# Out:
#          2016
# 0   4863300.0
# 1    741894.0
# 2   6931071.0
# 3   2988248.0
# 4  39250017.0

# %%
p2017 = population2017[['S0103_C01_001E']]
p2017["2017"] = p2017["S0103_C01_001E"]
# Out:
# /var/folders/6t/m3brq_pj49jd39l2d8j6jp000000gn/T/ipykernel_79327/750473076.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p2017["2017"] = p2017["S0103_C01_001E"]

# %%
p2017 = p2017.drop(['S0103_C01_001E'], axis=1)

# %%
#Population of all the states in the year 2017
p2017.head()
# Out:
#          2017
# 0   4874747.0
# 1    739795.0
# 2   7016270.0
# 3   3004279.0
# 4  39536653.0

# %%
p2018 = population2018[['S0103_C01_001E']]
p2018["2018"] = p2018["S0103_C01_001E"]
# Out:
# /var/folders/6t/m3brq_pj49jd39l2d8j6jp000000gn/T/ipykernel_79327/2805976968.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p2018["2018"] = p2018["S0103_C01_001E"]

# %%
p2018 = p2018.drop(['S0103_C01_001E'], axis=1)

# %%
#Population of all the states in the year 2018
p2018.head()
# Out:
#          2018
# 0   4887871.0
# 1    737438.0
# 2   7171646.0
# 3   3013825.0
# 4  39557045.0

# %%
p2019 = population2019[['S0103_C01_001E']]
p2019["2019"] = p2019["S0103_C01_001E"]
# Out:
# /var/folders/6t/m3brq_pj49jd39l2d8j6jp000000gn/T/ipykernel_79327/179462724.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p2019["2019"] = p2019["S0103_C01_001E"]

# %%
p2019 = p2019.drop(['S0103_C01_001E'], axis=1)

# %%
#Population of all the states in the year 2019
p2019.head()
# Out:
#          2019
# 0   4903185.0
# 1    731545.0
# 2   7278717.0
# 3   3017804.0
# 4  39512223.0

# %%
p2020 = population2020[['POPESTIMATE2020','POPESTIMATE2021']]
p2020["2020"] = p2020["POPESTIMATE2020"]
p2020["2021"] = p2020["POPESTIMATE2021"]
# Out:
# /var/folders/6t/m3brq_pj49jd39l2d8j6jp000000gn/T/ipykernel_79327/764932685.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p2020["2020"] = p2020["POPESTIMATE2020"]
# /var/folders/6t/m3brq_pj49jd39l2d8j6jp000000gn/T/ipykernel_79327/764932685.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p2020["2021"] = p2020["POPESTIMATE2021"]

# %%
p2020 = p2020.drop(['POPESTIMATE2020','POPESTIMATE2021'], axis=1)

# %%
#Population of all the states in the year 2020 & 2021
p2020
# Out:
#         2020      2021
# 0    5024803   5039877
# 1     732441    732673
# 2    7177986   7276316
# 3    3012232   3025891
# 4   39499738  39237836
# 5    5784308   5812069
# 6    3600260   3605597
# 7     991886   1003384
# 8     690093    670050
# 9   21569932  21781128
# 10  10725800  10799566
# 11   1451911   1441553
# 12   1847772   1900923
# 13  12785245  12671469
# 14   6785644   6805985
# 15   3188669   3193079
# 16   2935880   2934582
# 17   4503958   4509394
# 18   4651203   4624047
# 19   1362280   1372247
# 20   6172679   6165129
# 21   7022220   6984723
# 22  10067664  10050811
# 23   5707165   5707390
# 24   2956870   2949965
# 25   6154481   6168187
# 26   1086193   1104271
# 27   1961455   1963692
# 28   3114071   3143991
# 29   1377848   1388992
# 30   9279743   9267130
# 31   2117566   2115877
# 32  20154933  19835913
# 33  10457177  10551162
# 34    778962    774948
# 35  11790587  11780017
# 36   3962031   3986639
# 37   4241544   4246155
# 38  12989625  12964056
# ...

# %%
#concatenation of all the population data sets into one dataframe
population = pd.concat([p2015, p2016, p2017, p2018, p2019, p2020],axis=1)
population
# Out:
#                     NAME        2015        2016        2017        2018  \
# 0                Alabama   4858979.0   4863300.0   4874747.0   4887871.0
# 1                 Alaska    738432.0    741894.0    739795.0    737438.0
# 2                Arizona   6828065.0   6931071.0   7016270.0   7171646.0
# 3               Arkansas   2978204.0   2988248.0   3004279.0   3013825.0
# 4             California  39144818.0  39250017.0  39536653.0  39557045.0
# 5               Colorado   5456574.0   5540545.0   5607154.0   5695564.0
# 6            Connecticut   3590886.0   3576452.0   3588184.0   3572665.0
# 7               Delaware    945934.0    952065.0    961939.0    967171.0
# 8   District of Columbia    672228.0    681170.0    693972.0    702455.0
# 9                Florida  20271272.0  20612439.0  20984400.0  21299325.0
# 10               Georgia  10214860.0  10310371.0  10429379.0  10519475.0
# 11                Hawaii   1431603.0   1428557.0   1427538.0   1420491.0
# ...

# %%
#population cannot be decimals so converted it into integer
population["2015"] = population["2015"].apply(np.int64)
population["2016"] = population["2016"].apply(np.int64)
population["2017"] = population["2017"].apply(np.int64)
population["2018"] = population["2018"].apply(np.int64)
population["2019"] = population["2019"].apply(np.int64)
population["2020"] = population["2020"].apply(np.int64)
population["2021"] = population["2021"].apply(np.int64)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [186], in <cell line: 2>()
#       1 #population cannot be decimals so converted it into integer
# ----> 2 population["2015"] = population["2015"].apply(np.int64)
#       3 population["2016"] = population["2016"].apply(np.int64)
#       4 population["2017"] = population["2017"].apply(np.int64)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# ...

# %%
#As the above code didn't work, checking for any null values
population.isna().sum()
# Out:
# NAME    0
# 2015    1
# 2016    1
# 2017    1
# 2018    1
# 2019    1
# 2020    0
# 2021    0
# dtype: int64

# %%
#dropping the null values
population = population.drop(51)

# %%
#population cannot be decimals so converted it into integer
population["2015"] = population["2015"].apply(np.int64)
population["2016"] = population["2016"].apply(np.int64)
population["2017"] = population["2017"].apply(np.int64)
population["2018"] = population["2018"].apply(np.int64)
population["2019"] = population["2019"].apply(np.int64)
population["2020"] = population["2020"].apply(np.int64)
population["2021"] = population["2021"].apply(np.int64)

# %%
population
# Out:
#                     NAME      2015      2016      2017      2018      2019  \
# 0                Alabama   4858979   4863300   4874747   4887871   4903185
# 1                 Alaska    738432    741894    739795    737438    731545
# 2                Arizona   6828065   6931071   7016270   7171646   7278717
# 3               Arkansas   2978204   2988248   3004279   3013825   3017804
# 4             California  39144818  39250017  39536653  39557045  39512223
# 5               Colorado   5456574   5540545   5607154   5695564   5758736
# 6            Connecticut   3590886   3576452   3588184   3572665   3565287
# 7               Delaware    945934    952065    961939    967171    973764
# 8   District of Columbia    672228    681170    693972    702455    705749
# 9                Florida  20271272  20612439  20984400  21299325  21477737
# 10               Georgia  10214860  10310371  10429379  10519475  10617423
# ...

# %%
#Removal of inconsistent data
population = population.drop(8)
population
# Out:
#               NAME      2015      2016      2017      2018      2019  \
# 0          Alabama   4858979   4863300   4874747   4887871   4903185
# 1           Alaska    738432    741894    739795    737438    731545
# 2          Arizona   6828065   6931071   7016270   7171646   7278717
# 3         Arkansas   2978204   2988248   3004279   3013825   3017804
# 4       California  39144818  39250017  39536653  39557045  39512223
# 5         Colorado   5456574   5540545   5607154   5695564   5758736
# 6      Connecticut   3590886   3576452   3588184   3572665   3565287
# 7         Delaware    945934    952065    961939    967171    973764
# 9          Florida  20271272  20612439  20984400  21299325  21477737
# 10         Georgia  10214860  10310371  10429379  10519475  10617423
# 11          Hawaii   1431603   1428557   1427538   1420491   1415872
# 12           Idaho   1654930   1683140   1716943   1754208   1787065
# 13        Illinois  12859995  12801539  12802023  12741080  12671821
# ...

# %%
#Resetting the dataframe index after removal of few rows
population_final=population.reset_index()
population_final = population_final[["NAME","2015","2016","2017","2018","2019","2020","2021"]]

# %%
population_final["State Name"] = population_final["NAME"]
population_final["pop_2015"] = population_final["2015"]
population_final["pop_2016"] = population_final["2016"]
population_final["pop_2017"] = population_final["2017"]
population_final["pop_2018"] = population_final["2018"]
population_final["pop_2019"] = population_final["2019"]
population_final["pop_2020"] = population_final["2020"]
population_final["pop_2021"] = population_final["2021"]
population_final = population_final.drop(["NAME","2015","2016","2017"],axis=1)
population_final = population_final.drop(["2018","2019","2020","2021"],axis=1)

# %%
#Final population data set
population_final
# Out:
#         State Name  pop_2015  pop_2016  pop_2017  pop_2018  pop_2019  \
# 0          Alabama   4858979   4863300   4874747   4887871   4903185
# 1           Alaska    738432    741894    739795    737438    731545
# 2          Arizona   6828065   6931071   7016270   7171646   7278717
# 3         Arkansas   2978204   2988248   3004279   3013825   3017804
# 4       California  39144818  39250017  39536653  39557045  39512223
# 5         Colorado   5456574   5540545   5607154   5695564   5758736
# 6      Connecticut   3590886   3576452   3588184   3572665   3565287
# 7         Delaware    945934    952065    961939    967171    973764
# 8          Florida  20271272  20612439  20984400  21299325  21477737
# 9          Georgia  10214860  10310371  10429379  10519475  10617423
# 10          Hawaii   1431603   1428557   1427538   1420491   1415872
# 11           Idaho   1654930   1683140   1716943   1754208   1787065
# 12        Illinois  12859995  12801539  12802023  12741080  12671821
# ...

# %%
#Read the GDP data set 
US_GDP = pd.read_csv("GDP__ALL_AREAS_2005_2022.csv")

# %%
US_GDP.head()
# Out:
#    GeoFIPS  GeoName  Region TableName  LineCode IndustryClassification  \
# 0  "01000"  Alabama     5.0    SQGDP9       1.0                    ...
# 1  "01000"  Alabama     5.0    SQGDP9       2.0                    ...
# 2  "01000"  Alabama     5.0    SQGDP9       3.0                     11
# 3  "01000"  Alabama     5.0    SQGDP9       6.0                     21
# 4  "01000"  Alabama     5.0    SQGDP9      10.0                     22
#
#                                          Description  \
# 0                                All industry total
# 1                                Private industries
# 2        Agriculture, forestry, fishing and hunting
# 3     Mining, quarrying, and oil and gas extraction
# 4                                         Utilities
#
#                                Unit   2005:Q1   2005:Q2  ...   2020:Q1  \
# 0  Millions of chained 2012 dollars  182600.4  184625.7  ...  204004.9
# 1  Millions of chained 2012 dollars  151822.8  153771.4  ...  171274.1
# ...

# %%
#Subset of only required rows
US_GDP = US_GDP[US_GDP['Description']=='All industry total ']

# %%
US_GDP
# Out:
#       GeoFIPS               GeoName  Region TableName  LineCode  \
# 0     "01000"               Alabama     5.0    SQGDP9       1.0
# 27    "02000"                Alaska     8.0    SQGDP9       1.0
# 54    "04000"               Arizona     6.0    SQGDP9       1.0
# 81    "05000"              Arkansas     5.0    SQGDP9       1.0
# 108   "06000"            California     8.0    SQGDP9       1.0
# 135   "08000"              Colorado     7.0    SQGDP9       1.0
# 162   "09000"           Connecticut     1.0    SQGDP9       1.0
# 189   "10000"              Delaware     2.0    SQGDP9       1.0
# 216   "11000"  District of Columbia     2.0    SQGDP9       1.0
# 243   "12000"               Florida     5.0    SQGDP9       1.0
# 270   "13000"               Georgia     5.0    SQGDP9       1.0
# 297   "15000"                Hawaii     8.0    SQGDP9       1.0
# 324   "16000"                 Idaho     7.0    SQGDP9       1.0
# 351   "17000"              Illinois     3.0    SQGDP9       1.0
# ...

# %%
US_GDP.head()
# Out:
#      GeoFIPS     GeoName  Region TableName  LineCode IndustryClassification  \
# 0    "01000"     Alabama     5.0    SQGDP9       1.0                    ...
# 27   "02000"      Alaska     8.0    SQGDP9       1.0                    ...
# 54   "04000"     Arizona     6.0    SQGDP9       1.0                    ...
# 81   "05000"    Arkansas     5.0    SQGDP9       1.0                    ...
# 108  "06000"  California     8.0    SQGDP9       1.0                    ...
#
#              Description                              Unit    2005:Q1  \
# 0    All industry total   Millions of chained 2012 dollars   182600.4
# 27   All industry total   Millions of chained 2012 dollars    45176.1
# 54   All industry total   Millions of chained 2012 dollars   256521.4
# 81   All industry total   Millions of chained 2012 dollars   104693.3
# 108  All industry total   Millions of chained 2012 dollars  1896451.4
#
#        2005:Q2  ...    2020:Q1    2020:Q2    2020:Q3    2020:Q4    2021:Q1  \
# ...

# %%
#Changing the data type from string to integer for Converting Quaterly data into Annual data
US_GDP["2015"] = US_GDP["2015:Q4"].astype(float)

# %%
US_GDP["2016"] = US_GDP["2016:Q4"].astype(float)

# %%
US_GDP["2017"] = US_GDP["2017:Q4"].astype(float)

# %%
US_GDP["2018"] = US_GDP["2018:Q4"].astype(float)

# %%
US_GDP["2019"] = US_GDP["2019:Q4"].astype(float)

# %%
US_GDP["2020"] = US_GDP["2020:Q4"].astype(float)

# %%
US_GDP["2021"] = US_GDP["2021:Q4"].astype(float)

# %%
US_GDP
# Out:
#       GeoFIPS               GeoName  Region TableName  LineCode  \
# 0     "01000"               Alabama     5.0    SQGDP9       1.0
# 27    "02000"                Alaska     8.0    SQGDP9       1.0
# 54    "04000"               Arizona     6.0    SQGDP9       1.0
# 81    "05000"              Arkansas     5.0    SQGDP9       1.0
# 108   "06000"            California     8.0    SQGDP9       1.0
# 135   "08000"              Colorado     7.0    SQGDP9       1.0
# 162   "09000"           Connecticut     1.0    SQGDP9       1.0
# 189   "10000"              Delaware     2.0    SQGDP9       1.0
# 216   "11000"  District of Columbia     2.0    SQGDP9       1.0
# 243   "12000"               Florida     5.0    SQGDP9       1.0
# 270   "13000"               Georgia     5.0    SQGDP9       1.0
# 297   "15000"                Hawaii     8.0    SQGDP9       1.0
# 324   "16000"                 Idaho     7.0    SQGDP9       1.0
# 351   "17000"              Illinois     3.0    SQGDP9       1.0
# ...

# %%
GDP = US_GDP[['GeoName','2015','2016','2017','2018','2019','2020','2021']]

# %%
#Removal of inconsistent data
GDP = GDP.drop([216,1377,1404,1431,1458,1485,1512,1539,1566])

# %%
#Resetting the dataframe index after removal of few rows
GDP_final = GDP.reset_index()
GDP_final.head()
# Out:
#    index     GeoName       2015       2016       2017       2018       2019  \
# 0      0     Alabama   191778.0   195414.6   198544.8   201291.6   204465.8
# 1     27      Alaska    54541.5    53874.6    54159.9    53303.1    53585.5
# 2     54     Arizona   284969.4   294532.4   308216.8   317215.3   330709.7
# 3     81    Arkansas   112732.8   113734.1   114933.5   116546.1   118152.6
# 4    108  California  2369653.2  2456691.1  2599753.8  2674799.7  2772640.2
#
#         2020       2021
# 0   204400.7   213029.2
# 1    51069.4    51143.5
# 2   338182.1   357322.0
# 3   119689.9   124837.0
# 4  2746311.9  2942968.5

# %%
GDP_final = GDP_final[['GeoName','2015','2016','2017','2018','2019','2020','2021']]

# %%
GDP_final.head()
# Out:
#       GeoName       2015       2016       2017       2018       2019  \
# 0     Alabama   191778.0   195414.6   198544.8   201291.6   204465.8
# 1      Alaska    54541.5    53874.6    54159.9    53303.1    53585.5
# 2     Arizona   284969.4   294532.4   308216.8   317215.3   330709.7
# 3    Arkansas   112732.8   113734.1   114933.5   116546.1   118152.6
# 4  California  2369653.2  2456691.1  2599753.8  2674799.7  2772640.2
#
#         2020       2021
# 0   204400.7   213029.2
# 1    51069.4    51143.5
# 2   338182.1   357322.0
# 3   119689.9   124837.0
# 4  2746311.9  2942968.5

# %%
#Check for null values
GDP_final.isna().sum()
# Out:
# GeoName    0
# 2015       0
# 2016       0
# 2017       0
# 2018       0
# 2019       0
# 2020       0
# 2021       0
# dtype: int64

# %%
GDP_final["State Name"] = GDP_final["GeoName"]
GDP_final["GDP_2015"] = GDP_final["2015"]
GDP_final["GDP_2016"] = GDP_final["2016"]
GDP_final["GDP_2017"] = GDP_final["2017"]
GDP_final["GDP_2018"] = GDP_final["2018"]
GDP_final["GDP_2019"] = GDP_final["2019"]
GDP_final["GDP_2020"] = GDP_final["2020"]
GDP_final["GDP_2021"] = GDP_final["2021"]
GDP_final.head()
# Out:
#       GeoName       2015       2016       2017       2018       2019  \
# 0     Alabama   191778.0   195414.6   198544.8   201291.6   204465.8
# 1      Alaska    54541.5    53874.6    54159.9    53303.1    53585.5
# 2     Arizona   284969.4   294532.4   308216.8   317215.3   330709.7
# 3    Arkansas   112732.8   113734.1   114933.5   116546.1   118152.6
# 4  California  2369653.2  2456691.1  2599753.8  2674799.7  2772640.2
#
#         2020       2021  State Name   GDP_2015   GDP_2016   GDP_2017  \
# 0   204400.7   213029.2     Alabama   191778.0   195414.6   198544.8
# 1    51069.4    51143.5      Alaska    54541.5    53874.6    54159.9
# 2   338182.1   357322.0     Arizona   284969.4   294532.4   308216.8
# 3   119689.9   124837.0    Arkansas   112732.8   113734.1   114933.5
# 4  2746311.9  2942968.5  California  2369653.2  2456691.1  2599753.8
#
#     GDP_2018   GDP_2019   GDP_2020   GDP_2021
# 0   201291.6   204465.8   204400.7   213029.2
# ...

# %%
#Dropping unnecessary columns
GDP_final = GDP_final.drop(["GeoName","2015","2016","2017"],axis=1)
GDP_final = GDP_final.drop(["2018","2019","2020","2021"],axis=1)

# %%
#Final GDP dataset
GDP_final
# Out:
#         State Name   GDP_2015   GDP_2016   GDP_2017   GDP_2018   GDP_2019  \
# 0          Alabama   191778.0   195414.6   198544.8   201291.6   204465.8
# 1           Alaska    54541.5    53874.6    54159.9    53303.1    53585.5
# 2          Arizona   284969.4   294532.4   308216.8   317215.3   330709.7
# 3         Arkansas   112732.8   113734.1   114933.5   116546.1   118152.6
# 4       California  2369653.2  2456691.1  2599753.8  2674799.7  2772640.2
# 5         Colorado   315418.9   324234.0   335938.7   347071.2   364015.4
# 6      Connecticut   242686.1   243894.5   248790.5   249812.0   251582.1
# 7         Delaware    65537.4    62364.6    59973.4    62310.9    64930.1
# 8          Florida   865203.9   894374.5   924744.6   947689.8   975960.5
# 9          Georgia   494168.7   512918.2   532479.6   544533.3   562006.2
# 10          Hawaii    76537.4    77761.6    79300.0    79780.0    79502.4
# 11           Idaho    62938.7    65824.6    67926.6    71863.7    75072.0
# ...

# %%
#Read all the data files of Income statements for the fast food chains
wendys = pd.read_csv("The Wendy's Company - Income Statement.csv")
Starbucks = pd.read_csv("Starbucks Corporation - Income Statement.csv")
chipotle = pd.read_csv("Chipotle Mexican Grill, Inc. - Income Statement.csv")
dominos = pd.read_csv("Domino's Pizza, Inc. - Income Statement.csv")
Mcdonalds = pd.read_csv("McDonald's Corporation - Income Statement.csv")

# %%
wendys
# Out:
#                                Unnamed: 0   LTM.FQ-39   LTM.FQ-38   LTM.FQ-37  \
# 0                         Period End Date  2012-09-30  2012-12-30  2013-03-31
# 1                                 Revenue     2490381     2505242     2515737
# 2                    Revenue Growth (YoY)      0.0381      0.0304      0.0302
# 3                        Cost of Revenues    -1871412    -1881248    -1886609
# 4                            Gross Profit      618969      623994      629128
# 5                     Gross Profit Margin      0.2485      0.2491      0.2501
# 6                            R&D Expenses           0           0           0
# 7           Selling and Marketing Expense           0           0           0
# 8                General & Admin Expenses     -295067     -287808     -280814
# 9                       Other Inc / (Exp)     -282512     -286950     -328732
# 10                     Operating Expenses     -577579     -574758     -609546
# ...

# %%
#Considering only the Revenue of the fast food chain for analysis
wendys = wendys[wendys['Unnamed: 0'] == 'Revenue (Reported)']
wendys
# Out:
#             Unnamed: 0 LTM.FQ-39 LTM.FQ-38 LTM.FQ-37 LTM.FQ-36 LTM.FQ-35  \
# 27  Revenue (Reported)   2490381   2505242   2515737   2520413   2524884
#
#    LTM.FQ-34 LTM.FQ-33 LTM.FQ-32 LTM.FQ-31  ... LTM.FQ-9 LTM.FQ-8 LTM.FQ-7  \
# 27   2423669   2392178   2247713   2103604  ...  1705379  1672337  1686699
#
#    LTM.FQ-6 LTM.FQ-5 LTM.FQ-4 LTM.FQ-3 LTM.FQ-2 LTM.FQ-1      LTM
# 27  1733825  1789068  1880099  1898112  1896998  1925438  1969884
#
# [1 rows x 41 columns]

# %%
#Changing the data type from string to integer for Converting Quaterly data into Annual data
wendys["2015"] = wendys["LTM.FQ-26"].astype(float)
# Out:
# /var/folders/6t/m3brq_pj49jd39l2d8j6jp000000gn/T/ipykernel_79327/3739162052.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wendys["2015"] = wendys["LTM.FQ-26"].astype(float)

# %%
wendys["2016"] = wendys["LTM.FQ-22"].astype(float)
# Out:
# /var/folders/6t/m3brq_pj49jd39l2d8j6jp000000gn/T/ipykernel_79327/2922539055.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wendys["2016"] = wendys["LTM.FQ-22"].astype(float)

# %%
wendys["2017"] = wendys["LTM.FQ-18"].astype(float)
# Out:
# /var/folders/6t/m3brq_pj49jd39l2d8j6jp000000gn/T/ipykernel_79327/1338937241.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wendys["2017"] = wendys["LTM.FQ-18"].astype(float)

# %%
wendys["2018"] = wendys["LTM.FQ-14"].astype(float)
# Out:
# /var/folders/6t/m3brq_pj49jd39l2d8j6jp000000gn/T/ipykernel_79327/2683831420.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wendys["2018"] = wendys["LTM.FQ-14"].astype(float)

# %%
wendys["2019"] = wendys["LTM.FQ-10"].astype(float)
# Out:
# /var/folders/6t/m3brq_pj49jd39l2d8j6jp000000gn/T/ipykernel_79327/1086785209.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wendys["2019"] = wendys["LTM.FQ-10"].astype(float)

# %%
wendys["2020"] = wendys["LTM.FQ-6"].astype(float)
# Out:
# /var/folders/6t/m3brq_pj49jd39l2d8j6jp000000gn/T/ipykernel_79327/3151119546.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wendys["2020"] = wendys["LTM.FQ-6"].astype(float)

# %%
wendys["2021"] = wendys["LTM.FQ-2"].astype(float)
# Out:
# /var/folders/6t/m3brq_pj49jd39l2d8j6jp000000gn/T/ipykernel_79327/4149647416.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wendys["2021"] = wendys["LTM.FQ-2"].astype(float)

# %%
wendys.head()
# Out:
#             Unnamed: 0 LTM.FQ-39 LTM.FQ-38 LTM.FQ-37 LTM.FQ-36 LTM.FQ-35  \
# 27  Revenue (Reported)   2490381   2505242   2515737   2520413   2524884
#
#    LTM.FQ-34 LTM.FQ-33 LTM.FQ-32 LTM.FQ-31  ... LTM.FQ-2 LTM.FQ-1      LTM  \
# 27   2423669   2392178   2247713   2103604  ...  1896998  1925438  1969884
#
#          2015       2016       2017       2018       2019       2020  \
# 27  1870297.0  1435418.0  1223408.0  1589936.0  1709002.0  1733825.0
#
#          2021
# 27  1896998.0
#
# [1 rows x 48 columns]

# %%
wendys_revenue = wendys[['Unnamed: 0','2015','2016','2017','2018','2019','2020','2021']]

# %%
wendys_revenue
# Out:
#             Unnamed: 0       2015       2016       2017       2018       2019  \
# 27  Revenue (Reported)  1870297.0  1435418.0  1223408.0  1589936.0  1709002.0
#
#          2020       2021
# 27  1733825.0  1896998.0

# %%
Starbucks
# Out:
#                                Unnamed: 0   LTM.FQ-39   LTM.FQ-38   LTM.FQ-37  \
# 0                         Period End Date  2012-09-30  2012-12-30  2013-03-31
# 1                                 Revenue    13276800    13656800    14010400
# 2                    Revenue Growth (YoY)      0.1347      0.1207      0.1123
# 3                        Cost of Revenues    -9731400    -9950100   -10150200
# 4                            Gross Profit     3545400     3706700     3860200
# 5                     Gross Profit Margin       0.267      0.2714      0.2755
# 6                            R&D Expenses           0           0           0
# 7           Selling and Marketing Expense      -95500      -95500      -95500
# 8                General & Admin Expenses     -801200     -841600     -865000
# 9                       Other Inc / (Exp)     -556900     -606400     -605400
# 10                     Operating Expenses    -1453600    -1543500    -1565900
# ...

# %%
#Considering only the Revenue of the fast food chain for analysis
Starbucks = Starbucks[Starbucks['Unnamed: 0'] == 'Revenue (Reported)']
Starbucks
# Out:
#             Unnamed: 0 LTM.FQ-39 LTM.FQ-38 LTM.FQ-37 LTM.FQ-36 LTM.FQ-35  \
# 27  Revenue (Reported)  13276800  13656800  14010400  14442200  14866800
#
#    LTM.FQ-34 LTM.FQ-33 LTM.FQ-32 LTM.FQ-31  ...  LTM.FQ-9  LTM.FQ-8  LTM.FQ-7  \
# 27  15313200  15637500  16055800  16447800  ...  26662700  24061900  23518000
#
#     LTM.FQ-6  LTM.FQ-5  LTM.FQ-4  LTM.FQ-3  LTM.FQ-2  LTM.FQ-1       LTM
# 27  23170300  23842700  27117000  29060600  30361600  31329100  31982800
#
# [1 rows x 41 columns]

# %%
#Changing the data type from string to integer for Converting Quaterly data into Annual data
Starbucks["2015"] = Starbucks["LTM.FQ-27"].astype(float)
# Out:
# /var/folders/6t/m3brq_pj49jd39l2d8j6jp000000gn/T/ipykernel_79327/2460732407.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Starbucks["2015"] = Starbucks["LTM.FQ-27"].astype(float)

# %%
Starbucks["2016"] = Starbucks["LTM.FQ-22"].astype(float)
# Out:
# /var/folders/6t/m3brq_pj49jd39l2d8j6jp000000gn/T/ipykernel_79327/3281980035.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Starbucks["2016"] = Starbucks["LTM.FQ-22"].astype(float)

# %%
Starbucks["2017"] = Starbucks["LTM.FQ-19"].astype(float)
# Out:
# /var/folders/6t/m3brq_pj49jd39l2d8j6jp000000gn/T/ipykernel_79327/478287180.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Starbucks["2017"] = Starbucks["LTM.FQ-19"].astype(float)

# %%
Starbucks["2018"] = Starbucks["LTM.FQ-15"].astype(float)
# Out:
# /var/folders/6t/m3brq_pj49jd39l2d8j6jp000000gn/T/ipykernel_79327/1297020999.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Starbucks["2018"] = Starbucks["LTM.FQ-15"].astype(float)

# %%
Starbucks["2019"] = Starbucks["LTM.FQ-10"].astype(float)
# Out:
# /var/folders/6t/m3brq_pj49jd39l2d8j6jp000000gn/T/ipykernel_79327/475809906.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Starbucks["2019"] = Starbucks["LTM.FQ-10"].astype(float)

# %%
Starbucks["2020"] = Starbucks["LTM.FQ-7"].astype(float)
# Out:
# /var/folders/6t/m3brq_pj49jd39l2d8j6jp000000gn/T/ipykernel_79327/3609502404.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Starbucks["2020"] = Starbucks["LTM.FQ-7"].astype(float)

# %%
Starbucks["2021"] = Starbucks["LTM.FQ-3"].astype(float)
# Out:
# /var/folders/6t/m3brq_pj49jd39l2d8j6jp000000gn/T/ipykernel_79327/2470598982.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Starbucks["2021"] = Starbucks["LTM.FQ-3"].astype(float)

# %%
Starbucks
# Out:
#             Unnamed: 0 LTM.FQ-39 LTM.FQ-38 LTM.FQ-37 LTM.FQ-36 LTM.FQ-35  \
# 27  Revenue (Reported)  13276800  13656800  14010400  14442200  14866800
#
#    LTM.FQ-34 LTM.FQ-33 LTM.FQ-32 LTM.FQ-31  ...  LTM.FQ-2  LTM.FQ-1       LTM  \
# 27  15313200  15637500  16055800  16447800  ...  30361600  31329100  31982800
#
#           2015        2016        2017        2018        2019        2020  \
# 27  19162700.0  21675300.0  22386800.0  24719500.0  26973000.0  23518000.0
#
#           2021
# 27  29060600.0
#
# [1 rows x 48 columns]

# %%
starbucks_revenue = Starbucks[['Unnamed: 0','2015','2016','2017','2018','2019','2020','2021']]

# %%
starbucks_revenue
# Out:
#             Unnamed: 0        2015        2016        2017        2018  \
# 27  Revenue (Reported)  19162700.0  21675300.0  22386800.0  24719500.0
#
#           2019        2020        2021
# 27  26973000.0  23518000.0  29060600.0

# %%
chipotle
# Out:
#                                Unnamed: 0   LTM.FQ-39   LTM.FQ-38   LTM.FQ-37  \
# 0                         Period End Date  2012-09-30  2012-12-31  2013-03-31
# 1                                 Revenue     2628812     2731224     2817372
# 2                    Revenue Growth (YoY)      0.2197      0.2034      0.1735
# 3                        Cost of Revenues    -1629877    -1704274    -1763868
# 4                            Gross Profit      998935     1026950     1053504
# 5                     Gross Profit Margin        0.38       0.376      0.3739
# 6                            R&D Expenses           0           0           0
# 7           Selling and Marketing Expense      -31902      -34999      -34999
# 8                General & Admin Expenses     -178223     -183409     -178286
# 9                       Other Inc / (Exp)     -341265     -352677     -366534
# 10                     Operating Expenses     -551390     -571085     -579819
# ...

# %%
#Considering only the Revenue of the fast food chain for analysis
chipotle = chipotle[chipotle['Unnamed: 0'] == 'Revenue (Reported)']
chipotle
# Out:
#             Unnamed: 0 LTM.FQ-39 LTM.FQ-38 LTM.FQ-37 LTM.FQ-36 LTM.FQ-35  \
# 27  Revenue (Reported)   2628812   2731224   2817372   2943226   3069605
#
#    LTM.FQ-34 LTM.FQ-33 LTM.FQ-32 LTM.FQ-31  ... LTM.FQ-9 LTM.FQ-8 LTM.FQ-7  \
# 27   3214591   3392003   3625290   3882605  ...  6997141  8361879  5817148
#
#    LTM.FQ-6 LTM.FQ-5 LTM.FQ-4 LTM.FQ-3 LTM.FQ-2 LTM.FQ-1      LTM
# 27  5984634  6315437  6843237  7194138  7547061  7826025  8146826
#
# [1 rows x 41 columns]

# %%
#Changing the data type from string to integer for Converting Quaterly data into Annual data
chipotle["2015"] = chipotle["LTM.FQ-26"].astype(float)
chipotle["2016"] = chipotle["LTM.FQ-22"].astype(float)
chipotle["2017"] = chipotle["LTM.FQ-18"].astype(float)
chipotle["2018"] = chipotle["LTM.FQ-14"].astype(float)
chipotle["2019"] = chipotle["LTM.FQ-10"].astype(float)
chipotle["2020"] = chipotle["LTM.FQ-6"].astype(float)
chipotle["2021"] = chipotle["LTM.FQ-2"].astype(float)
# Out:
# /var/folders/6t/m3brq_pj49jd39l2d8j6jp000000gn/T/ipykernel_79327/1367165789.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chipotle["2015"] = chipotle["LTM.FQ-26"].astype(float)
# /var/folders/6t/m3brq_pj49jd39l2d8j6jp000000gn/T/ipykernel_79327/1367165789.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chipotle["2016"] = chipotle["LTM.FQ-22"].astype(float)
# /var/folders/6t/m3brq_pj49jd39l2d8j6jp000000gn/T/ipykernel_79327/1367165789.py:4: SettingWithCopyWarning:
# ...

# %%
chipotle
# Out:
#             Unnamed: 0 LTM.FQ-39 LTM.FQ-38 LTM.FQ-37 LTM.FQ-36 LTM.FQ-35  \
# 27  Revenue (Reported)   2628812   2731224   2817372   2943226   3069605
#
#    LTM.FQ-34 LTM.FQ-33 LTM.FQ-32 LTM.FQ-31  ... LTM.FQ-2 LTM.FQ-1      LTM  \
# 27   3214591   3392003   3625290   3882605  ...  7547061  7826025  8146826
#
#          2015       2016       2017       2018       2019       2020  \
# 27  4501223.0  3904384.0  4476412.0  4864985.0  5586369.0  5984634.0
#
#          2021
# 27  7547061.0
#
# [1 rows x 48 columns]

# %%
chipotle_revenue = chipotle[['Unnamed: 0','2015','2016','2017','2018','2019','2020','2021']]

# %%
Mcdonalds
# Out:
#                                Unnamed: 0   LTM.FQ-39   LTM.FQ-38   LTM.FQ-37  \
# 0                         Period End Date  2012-09-30  2012-12-31  2013-03-31
# 1                                 Revenue    27437600    27567000    27625700
# 2                    Revenue Growth (YoY)      0.0394      0.0208      0.0067
# 3                        Cost of Revenues   -16636000   -16750700   -16842800
# 4                            Gross Profit    10801600    10816300    10782900
# 5                     Gross Profit Margin      0.3937      0.3924      0.3903
# 6                            R&D Expenses           0           0           0
# 7       Selling, General & Admin Expenses    -2491900    -2455200    -2459200
# 8                       Other Inc / (Exp)      164500      206500      219900
# 9                      Operating Expenses    -2327400    -2248700    -2239300
# 10                       Operating Income     8474200     8567600     8543600
# ...

# %%
#Considering only the Revenue of the fast food chain for analysis
Mcdonalds = Mcdonalds[Mcdonalds['Unnamed: 0'] == 'Revenue (Reported)']
Mcdonalds
# Out:
#             Unnamed: 0 LTM.FQ-39 LTM.FQ-38 LTM.FQ-37 LTM.FQ-36 LTM.FQ-35  \
# 26  Revenue (Reported)  27437600  27567000  27625700  27793600  27964600
#
#    LTM.FQ-34 LTM.FQ-33 LTM.FQ-32 LTM.FQ-31  ...  LTM.FQ-9  LTM.FQ-8  LTM.FQ-7  \
# 26  28105700  28200700  28298600  27962300  ...  21054700  19406400  19322200
#
#     LTM.FQ-6  LTM.FQ-5  LTM.FQ-4  LTM.FQ-3  LTM.FQ-2  LTM.FQ-1       LTM
# 26  19207800  19618000  21744400  22527600  23222900  23763900  23594400
#
# [1 rows x 41 columns]

# %%
#Changing the data type from string to integer for Converting Quaterly data into Annual data
Mcdonalds["2015"] = Mcdonalds["LTM.FQ-26"].astype(float)
Mcdonalds["2016"] = Mcdonalds["LTM.FQ-22"].astype(float)
Mcdonalds["2017"] = Mcdonalds["LTM.FQ-18"].astype(float)
Mcdonalds["2018"] = Mcdonalds["LTM.FQ-14"].astype(float)
Mcdonalds["2019"] = Mcdonalds["LTM.FQ-10"].astype(float)
Mcdonalds["2020"] = Mcdonalds["LTM.FQ-6"].astype(float)
Mcdonalds["2021"] = Mcdonalds["LTM.FQ-2"].astype(float)
# Out:
# /var/folders/6t/m3brq_pj49jd39l2d8j6jp000000gn/T/ipykernel_79327/425783841.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Mcdonalds["2015"] = Mcdonalds["LTM.FQ-26"].astype(float)
# /var/folders/6t/m3brq_pj49jd39l2d8j6jp000000gn/T/ipykernel_79327/425783841.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Mcdonalds["2016"] = Mcdonalds["LTM.FQ-22"].astype(float)
# /var/folders/6t/m3brq_pj49jd39l2d8j6jp000000gn/T/ipykernel_79327/425783841.py:4: SettingWithCopyWarning:
# ...

# %%
Mcdonalds_revenue = Mcdonalds[['Unnamed: 0','2015','2016','2017','2018','2019','2020','2021']]

# %%
Mcdonalds_revenue
# Out:
#             Unnamed: 0        2015        2016        2017        2018  \
# 26  Revenue (Reported)  25413000.0  24621900.0  22820400.0  21257900.0
#
#           2019        2020        2021
# 26  21364400.0  19207800.0  23222900.0

# %%
dominos
# Out:
#                                Unnamed: 0   LTM.FQ-39   LTM.FQ-38   LTM.FQ-37  \
# 0                         Period End Date  2012-12-30  2013-03-24  2013-06-16
# 1                                 Revenue     1678439     1711469     1749354
# 2                    Revenue Growth (YoY)      0.0159      0.0388      0.0675
# 3                        Cost of Revenues    -1177101    -1194974    -1221479
# 4                            Gross Profit      501338      516495      527875
# 5                     Gross Profit Margin      0.2987      0.3018      0.3018
# 6                            R&D Expenses           0           0           0
# 7           Selling and Marketing Expense           0           0           0
# 8                General & Admin Expenses     -219007     -227334     -230651
# 9                       Other Inc / (Exp)           0        1800        1800
# 10                     Operating Expenses     -219007     -225534     -228851
# ...

# %%
#Considering only the Revenue of the fast food chain for analysis
dominos = dominos[dominos['Unnamed: 0'] == 'Revenue (Reported)']
dominos
# Out:
#             Unnamed: 0 LTM.FQ-39 LTM.FQ-38 LTM.FQ-37 LTM.FQ-36 LTM.FQ-35  \
# 27  Revenue (Reported)   1678439   1711469   1749354   1775326   1802223
#
#    LTM.FQ-34 LTM.FQ-33 LTM.FQ-32 LTM.FQ-31  ... LTM.FQ-9 LTM.FQ-8 LTM.FQ-7  \
# 27   1838458   1874911   1917430   1993833  ...  3764289  3911196  4117411
#
#    LTM.FQ-6 LTM.FQ-5 LTM.FQ-4 LTM.FQ-3 LTM.FQ-2 LTM.FQ-1      LTM
# 27  4228007  4340456  4370727  4357373  4384824  4417534  4488140
#
# [1 rows x 41 columns]

# %%
#Changing the data type from string to integer for Converting Quaterly data into Annual data
dominos["2015"] = dominos["LTM.FQ-28"].astype(float)
dominos["2016"] = dominos["LTM.FQ-24"].astype(float)
dominos["2017"] = dominos["LTM.FQ-19"].astype(float)
dominos["2018"] = dominos["LTM.FQ-15"].astype(float)
dominos["2019"] = dominos["LTM.FQ-11"].astype(float)
dominos["2020"] = dominos["LTM.FQ-8"].astype(float)
dominos["2021"] = dominos["LTM.FQ-4"].astype(float)
# Out:
# /var/folders/6t/m3brq_pj49jd39l2d8j6jp000000gn/T/ipykernel_79327/1693106023.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dominos["2015"] = dominos["LTM.FQ-28"].astype(float)
# /var/folders/6t/m3brq_pj49jd39l2d8j6jp000000gn/T/ipykernel_79327/1693106023.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dominos["2016"] = dominos["LTM.FQ-24"].astype(float)
# /var/folders/6t/m3brq_pj49jd39l2d8j6jp000000gn/T/ipykernel_79327/1693106023.py:4: SettingWithCopyWarning:
# ...

# %%
dominos_revenue = dominos[['Unnamed: 0','2015','2016','2017','2018','2019','2020','2021']]
dominos_revenue
# Out:
#             Unnamed: 0       2015       2016       2017       2018       2019  \
# 27  Revenue (Reported)  2118295.0  2394376.0  2787979.0  3432867.0  3618774.0
#
#          2020       2021
# 27  3911196.0  4370727.0

# %%
#concatenation of all the Revenue data sets of different fastfood chains into one dataframe as Revenue
Revenue = pd.concat([wendys_revenue, starbucks_revenue, chipotle_revenue, Mcdonalds_revenue, dominos_revenue])
Revenue
# Out:
#             Unnamed: 0        2015        2016        2017        2018  \
# 27  Revenue (Reported)   1870297.0   1435418.0   1223408.0   1589936.0
# 27  Revenue (Reported)  19162700.0  21675300.0  22386800.0  24719500.0
# 27  Revenue (Reported)   4501223.0   3904384.0   4476412.0   4864985.0
# 26  Revenue (Reported)  25413000.0  24621900.0  22820400.0  21257900.0
# 27  Revenue (Reported)   2118295.0   2394376.0   2787979.0   3432867.0
#
#           2019        2020        2021
# 27   1709002.0   1733825.0   1896998.0
# 27  26973000.0  23518000.0  29060600.0
# 27   5586369.0   5984634.0   7547061.0
# 26  21364400.0  19207800.0  23222900.0
# 27   3618774.0   3911196.0   4370727.0

# %%
Fastfood_chain = ['wendys', 'starbucks', 'chipotle', 'Mcdonalds', 'dominos']

# %%
Revenue['Fastfood_chain'] = Fastfood_chain

# %%
Revenue
# Out:
#             Unnamed: 0        2015        2016        2017        2018  \
# 27  Revenue (Reported)   1870297.0   1435418.0   1223408.0   1589936.0
# 27  Revenue (Reported)  19162700.0  21675300.0  22386800.0  24719500.0
# 27  Revenue (Reported)   4501223.0   3904384.0   4476412.0   4864985.0
# 26  Revenue (Reported)  25413000.0  24621900.0  22820400.0  21257900.0
# 27  Revenue (Reported)   2118295.0   2394376.0   2787979.0   3432867.0
#
#           2019        2020        2021 Fastfood_chain
# 27   1709002.0   1733825.0   1896998.0         wendys
# 27  26973000.0  23518000.0  29060600.0      starbucks
# 27   5586369.0   5984634.0   7547061.0       chipotle
# 26  21364400.0  19207800.0  23222900.0      Mcdonalds
# 27   3618774.0   3911196.0   4370727.0        dominos

# %%
Revenue= Revenue.drop(['Unnamed: 0'], axis=1)

# %%
Revenue
# Out:
#           2015        2016        2017        2018        2019        2020  \
# 27   1870297.0   1435418.0   1223408.0   1589936.0   1709002.0   1733825.0
# 27  19162700.0  21675300.0  22386800.0  24719500.0  26973000.0  23518000.0
# 27   4501223.0   3904384.0   4476412.0   4864985.0   5586369.0   5984634.0
# 26  25413000.0  24621900.0  22820400.0  21257900.0  21364400.0  19207800.0
# 27   2118295.0   2394376.0   2787979.0   3432867.0   3618774.0   3911196.0
#
#           2021 Fastfood_chain
# 27   1896998.0         wendys
# 27  29060600.0      starbucks
# 27   7547061.0       chipotle
# 26  23222900.0      Mcdonalds
# 27   4370727.0        dominos

# %%
order = [7,0,1,2,3,4,5,6]

# %%
Revenue = Revenue[[Revenue.columns[i] for i in order]]

# %%
Revenue
# Out:
#    Fastfood_chain        2015        2016        2017        2018        2019  \
# 27         wendys   1870297.0   1435418.0   1223408.0   1589936.0   1709002.0
# 27      starbucks  19162700.0  21675300.0  22386800.0  24719500.0  26973000.0
# 27       chipotle   4501223.0   3904384.0   4476412.0   4864985.0   5586369.0
# 26      Mcdonalds  25413000.0  24621900.0  22820400.0  21257900.0  21364400.0
# 27        dominos   2118295.0   2394376.0   2787979.0   3432867.0   3618774.0
#
#           2020        2021
# 27   1733825.0   1896998.0
# 27  23518000.0  29060600.0
# 27   5984634.0   7547061.0
# 26  19207800.0  23222900.0
# 27   3911196.0   4370727.0

# %%
#Resetting the dataframe index after removal of few rows
Revenue_final = Revenue.reset_index()
Revenue_final
# Out:
#    index Fastfood_chain        2015        2016        2017        2018  \
# 0     27         wendys   1870297.0   1435418.0   1223408.0   1589936.0
# 1     27      starbucks  19162700.0  21675300.0  22386800.0  24719500.0
# 2     27       chipotle   4501223.0   3904384.0   4476412.0   4864985.0
# 3     26      Mcdonalds  25413000.0  24621900.0  22820400.0  21257900.0
# 4     27        dominos   2118295.0   2394376.0   2787979.0   3432867.0
#
#          2019        2020        2021
# 0   1709002.0   1733825.0   1896998.0
# 1  26973000.0  23518000.0  29060600.0
# 2   5586369.0   5984634.0   7547061.0
# 3  21364400.0  19207800.0  23222900.0
# 4   3618774.0   3911196.0   4370727.0

# %%
Revenue_final = Revenue_final[["Fastfood_chain","2015","2016","2017","2018","2019","2020","2021"]]

# %%
Revenue_final["Revenue_2015"] = Revenue_final["2015"]
Revenue_final["Revenue_2016"] = Revenue_final["2016"]
Revenue_final["Revenue_2017"] = Revenue_final["2017"]
Revenue_final["Revenue_2018"] = Revenue_final["2018"]
Revenue_final["Revenue_2019"] = Revenue_final["2019"]
Revenue_final["Revenue_2020"] = Revenue_final["2020"]
Revenue_final["Revenue_2021"] = Revenue_final["2021"]
Revenue_final.head()
# Out:
#   Fastfood_chain        2015        2016        2017        2018        2019  \
# 0         wendys   1870297.0   1435418.0   1223408.0   1589936.0   1709002.0
# 1      starbucks  19162700.0  21675300.0  22386800.0  24719500.0  26973000.0
# 2       chipotle   4501223.0   3904384.0   4476412.0   4864985.0   5586369.0
# 3      Mcdonalds  25413000.0  24621900.0  22820400.0  21257900.0  21364400.0
# 4        dominos   2118295.0   2394376.0   2787979.0   3432867.0   3618774.0
#
#          2020        2021  Revenue_2015  Revenue_2016  Revenue_2017  \
# 0   1733825.0   1896998.0     1870297.0     1435418.0     1223408.0
# 1  23518000.0  29060600.0    19162700.0    21675300.0    22386800.0
# 2   5984634.0   7547061.0     4501223.0     3904384.0     4476412.0
# 3  19207800.0  23222900.0    25413000.0    24621900.0    22820400.0
# 4   3911196.0   4370727.0     2118295.0     2394376.0     2787979.0
#
#    Revenue_2018  Revenue_2019  Revenue_2020  Revenue_2021
# ...

# %%
#Dropping unnecessary columns
Revenue_final = Revenue_final.drop(["2015","2016","2017"],axis=1)
Revenue_final = Revenue_final.drop(["2018","2019","2020","2021"],axis=1)
Revenue_final
# Out:
#   Fastfood_chain  Revenue_2015  Revenue_2016  Revenue_2017  Revenue_2018  \
# 0         wendys     1870297.0     1435418.0     1223408.0     1589936.0
# 1      starbucks    19162700.0    21675300.0    22386800.0    24719500.0
# 2       chipotle     4501223.0     3904384.0     4476412.0     4864985.0
# 3      Mcdonalds    25413000.0    24621900.0    22820400.0    21257900.0
# 4        dominos     2118295.0     2394376.0     2787979.0     3432867.0
#
#    Revenue_2019  Revenue_2020  Revenue_2021
# 0     1709002.0     1733825.0     1896998.0
# 1    26973000.0    23518000.0    29060600.0
# 2     5586369.0     5984634.0     7547061.0
# 3    21364400.0    19207800.0    23222900.0
# 4     3618774.0     3911196.0     4370727.0

# %%
#checking for null values
Revenue_final.isna().sum()
# Out:
# Fastfood_chain    0
# Revenue_2015      0
# Revenue_2016      0
# Revenue_2017      0
# Revenue_2018      0
# Revenue_2019      0
# Revenue_2020      0
# Revenue_2021      0
# dtype: int64

# %%
#Converting float to integer to remove decimals
Revenue_final["Revenue_2015"] = Revenue_final["Revenue_2015"].apply(np.int64)
Revenue_final["Revenue_2016"] = Revenue_final["Revenue_2016"].apply(np.int64)
Revenue_final["Revenue_2017"] = Revenue_final["Revenue_2017"].apply(np.int64)
Revenue_final["Revenue_2018"] = Revenue_final["Revenue_2018"].apply(np.int64)
Revenue_final["Revenue_2019"] = Revenue_final["Revenue_2019"].apply(np.int64)
Revenue_final["Revenue_2020"] = Revenue_final["Revenue_2020"].apply(np.int64)
Revenue_final["Revenue_2021"] = Revenue_final["Revenue_2021"].apply(np.int64)

# %%
#Final Revenue data set
Revenue_final
# Out:
#   Fastfood_chain  Revenue_2015  Revenue_2016  Revenue_2017  Revenue_2018  \
# 0         wendys       1870297       1435418       1223408       1589936
# 1      starbucks      19162700      21675300      22386800      24719500
# 2       chipotle       4501223       3904384       4476412       4864985
# 3      Mcdonalds      25413000      24621900      22820400      21257900
# 4        dominos       2118295       2394376       2787979       3432867
#
#    Revenue_2019  Revenue_2020  Revenue_2021
# 0       1709002       1733825       1896998
# 1      26973000      23518000      29060600
# 2       5586369       5984634       7547061
# 3      21364400      19207800      23222900
# 4       3618774       3911196       4370727

# %%
#percapita income is GDP divided by population of USA 
population_final['percapita_2015'] = GDP_final['GDP_2015']/population_final['pop_2015']

# %%
population_final['percapita_2016'] = GDP_final['GDP_2016']/population_final['pop_2016']

# %%
population_final['percapita_2017'] = GDP_final['GDP_2017']/population_final['pop_2017']
population_final['percapita_2018'] = GDP_final['GDP_2018']/population_final['pop_2018']
population_final['percapita_2019'] = GDP_final['GDP_2019']/population_final['pop_2019']
population_final['percapita_2020'] = GDP_final['GDP_2020']/population_final['pop_2020']
population_final['percapita_2021'] = GDP_final['GDP_2021']/population_final['pop_2021']

# %%
population_final.head()
# Out:
#    State Name  pop_2015  pop_2016  pop_2017  pop_2018  pop_2019  pop_2020  \
# 0     Alabama   4858979   4863300   4874747   4887871   4903185   5024803
# 1      Alaska    738432    741894    739795    737438    731545    732441
# 2     Arizona   6828065   6931071   7016270   7171646   7278717   7177986
# 3    Arkansas   2978204   2988248   3004279   3013825   3017804   3012232
# 4  California  39144818  39250017  39536653  39557045  39512223  39499738
#
#    pop_2021  percapita_2016  percapita_2017  percapita_2018  percapita_2019  \
# 0   5039877        0.040181        0.040729        0.041182        0.041701
# 1    732673        0.072618        0.073209        0.072281        0.073250
# 2   7276316        0.042495        0.043929        0.044232        0.045435
# 3   3025891        0.038060        0.038257        0.038670        0.039152
# 4  39237836        0.062591        0.065756        0.067619        0.070172
#
#    percapita_2020  percapita_2021  percapita_2015
# ...

# %%
percapita_final = population_final[['State Name','percapita_2015','percapita_2016','percapita_2017','percapita_2018','percapita_2019','percapita_2020','percapita_2021']]

# %%
#Final dataset of percapita income
percapita_final.head()
# Out:
#    State Name  percapita_2015  percapita_2016  percapita_2017  percapita_2018  \
# 0     Alabama        0.039469        0.040181        0.040729        0.041182
# 1      Alaska        0.073861        0.072618        0.073209        0.072281
# 2     Arizona        0.041735        0.042495        0.043929        0.044232
# 3    Arkansas        0.037853        0.038060        0.038257        0.038670
# 4  California        0.060536        0.062591        0.065756        0.067619
#
#    percapita_2019  percapita_2020  percapita_2021
# 0        0.041701        0.040678        0.042269
# 1        0.073250        0.069725        0.069804
# 2        0.045435        0.047114        0.049108
# 3        0.039152        0.039735        0.041256
# 4        0.070172        0.069527        0.075003

# %%
population_final = population_final.drop(['percapita_2015','percapita_2016','percapita_2017','percapita_2018','percapita_2019','percapita_2020','percapita_2021'], axis=1)

# %%
population_final.head()
# Out:
#    State Name  pop_2015  pop_2016  pop_2017  pop_2018  pop_2019  pop_2020  \
# 0     Alabama   4858979   4863300   4874747   4887871   4903185   5024803
# 1      Alaska    738432    741894    739795    737438    731545    732441
# 2     Arizona   6828065   6931071   7016270   7171646   7278717   7177986
# 3    Arkansas   2978204   2988248   3004279   3013825   3017804   3012232
# 4  California  39144818  39250017  39536653  39557045  39512223  39499738
#
#    pop_2021
# 0   5039877
# 1    732673
# 2   7276316
# 3   3025891
# 4  39237836

# %%
#Read the data set with all the personal consumption information
US_personalconsumption = pd.read_csv("personal_consumption_ALL_AREAS_1997_2021.csv")

# %%
US_personalconsumption.head()
# Out:
#     GeoFIPS  GeoName  Region TableName  LineCode IndustryClassification  \
# 0   "01000"  Alabama     5.0    SAPCE1       1.0                    ...
# 1   "01000"  Alabama     5.0    SAPCE1       2.0                    ...
# 2   "01000"  Alabama     5.0    SAPCE1       3.0                    ...
# 3   "01000"  Alabama     5.0    SAPCE1       4.0                    ...
# 4   "01000"  Alabama     5.0    SAPCE1       5.0                    ...
#
#                                        Description  \
# 0               Personal consumption expenditures
# 1                                           Goods
# 2                                   Durable goods
# 3                        Motor vehicles and parts
# 4     Furnishings and durable household equipment
#
#                           Unit     1997     1998  ...      2012      2013  \
# 0  Millions of current dollars  77070.9  80481.0  ...  140347.7  144027.9
# 1  Millions of current dollars  29995.6  30983.5  ...   53205.7   54377.8
# ...

# %%
US_personalconsumption = US_personalconsumption[US_personalconsumption['Description']=='   Food and beverages purchased for off-premises consumption ']

# %%
US_personalconsumption.head()
# Out:
#       GeoFIPS     GeoName  Region TableName  LineCode IndustryClassification  \
# 8     "01000"     Alabama     5.0    SAPCE1       9.0                    ...
# 32    "02000"      Alaska     8.0    SAPCE1       9.0                    ...
# 56    "04000"     Arizona     6.0    SAPCE1       9.0                    ...
# 80    "05000"    Arkansas     5.0    SAPCE1       9.0                    ...
# 104   "06000"  California     8.0    SAPCE1       9.0                    ...
#
#                                            Description  \
# 8       Food and beverages purchased for off-premis...
# 32      Food and beverages purchased for off-premis...
# 56      Food and beverages purchased for off-premis...
# 80      Food and beverages purchased for off-premis...
# 104     Food and beverages purchased for off-premis...
#
#                             Unit     1997     1998  ...      2012      2013  \
# 8    Millions of current dollars   7747.3   7866.4  ...   11840.2   11889.6
# ...

# %%
#Subset of only required rows
personal_consumption = US_personalconsumption[['GeoName','2015','2016','2017','2018','2019','2020','2021']]

# %%
personal_consumption
# Out:
#                    GeoName      2015      2016      2017      2018      2019  \
# 8                  Alabama   12471.7   12741.1   13003.7   13425.9   13851.2
# 32                  Alaska    2773.3    2721.7    2707.8    2741.0    2778.2
# 56                 Arizona   18537.3   19046.5   20009.6   20494.1   20787.4
# 80                Arkansas    7206.8    7445.5    7595.0    7678.9    7729.2
# 104             California  113368.8  116078.5  119796.3  123086.1  127768.6
# 128               Colorado   17381.8   18325.6   19271.2   19810.5   20636.1
# 152            Connecticut   11711.5   11809.7   12121.2   12072.1   12171.1
# 176               Delaware    2885.5    2884.9    2949.4    3061.0    3104.2
# 200   District of Columbia    3445.2    3479.9    3629.5    3704.5    3810.3
# 224                Florida   61698.9   63644.8   66212.9   69175.4   72444.9
# 248                Georgia   29235.7   29619.4   31407.8   32300.4   33344.6
# ...

# %%
#Removal of inconsistent data
personal_consumption = personal_consumption.drop([200,1232,1256,1280,1304,1328,1352,1376,1400])

# %%
#Resetting the dataframe index after removal of few rows
personal_consumption_final = personal_consumption.reset_index()
personal_consumption_final.head()
# Out:
#    index     GeoName      2015      2016      2017      2018      2019  \
# 0      8     Alabama   12471.7   12741.1   13003.7   13425.9   13851.2
# 1     32      Alaska    2773.3    2721.7    2707.8    2741.0    2778.2
# 2     56     Arizona   18537.3   19046.5   20009.6   20494.1   20787.4
# 3     80    Arkansas    7206.8    7445.5    7595.0    7678.9    7729.2
# 4    104  California  113368.8  116078.5  119796.3  123086.1  127768.6
#
#        2020      2021
# 0   15107.6   16433.8
# 1    2902.5    3018.4
# 2   23061.1   24348.5
# 3    8549.9    9458.6
# 4  140352.0  151641.2

# %%
personal_consumption_final = personal_consumption_final[['GeoName','2015','2016','2017','2018','2019','2020','2021']]
personal_consumption_final.head()
# Out:
#       GeoName      2015      2016      2017      2018      2019      2020  \
# 0     Alabama   12471.7   12741.1   13003.7   13425.9   13851.2   15107.6
# 1      Alaska    2773.3    2721.7    2707.8    2741.0    2778.2    2902.5
# 2     Arizona   18537.3   19046.5   20009.6   20494.1   20787.4   23061.1
# 3    Arkansas    7206.8    7445.5    7595.0    7678.9    7729.2    8549.9
# 4  California  113368.8  116078.5  119796.3  123086.1  127768.6  140352.0
#
#        2021
# 0   16433.8
# 1    3018.4
# 2   24348.5
# 3    9458.6
# 4  151641.2

# %%
#checking for null values
personal_consumption_final.isna().sum()
# Out:
# GeoName    0
# 2015       0
# 2016       0
# 2017       0
# 2018       0
# 2019       0
# 2020       0
# 2021       0
# dtype: int64

# %%
personal_consumption_final["State Name"] = personal_consumption_final["GeoName"]
personal_consumption_final["personal_consumption_2015"] = personal_consumption_final["2015"]
personal_consumption_final["personal_consumption_2016"] = personal_consumption_final["2016"]
personal_consumption_final["personal_consumption_2017"] = personal_consumption_final["2017"]
personal_consumption_final["personal_consumption_2018"] = personal_consumption_final["2018"]
personal_consumption_final["personal_consumption_2019"] = personal_consumption_final["2019"]
personal_consumption_final["personal_consumption_2020"] = personal_consumption_final["2020"]
personal_consumption_final["personal_consumption_2021"] = personal_consumption_final["2021"]
personal_consumption_final.head()
# Out:
#       GeoName      2015      2016      2017      2018      2019      2020  \
# 0     Alabama   12471.7   12741.1   13003.7   13425.9   13851.2   15107.6
# 1      Alaska    2773.3    2721.7    2707.8    2741.0    2778.2    2902.5
# 2     Arizona   18537.3   19046.5   20009.6   20494.1   20787.4   23061.1
# 3    Arkansas    7206.8    7445.5    7595.0    7678.9    7729.2    8549.9
# 4  California  113368.8  116078.5  119796.3  123086.1  127768.6  140352.0
#
#        2021  State Name  personal_consumption_2015  personal_consumption_2016  \
# 0   16433.8     Alabama                    12471.7                    12741.1
# 1    3018.4      Alaska                     2773.3                     2721.7
# 2   24348.5     Arizona                    18537.3                    19046.5
# 3    9458.6    Arkansas                     7206.8                     7445.5
# 4  151641.2  California                   113368.8                   116078.5
#
# ...

# %%
#Dropping unnecessary columns
personal_consumption_final = personal_consumption_final.drop(["GeoName","2015","2016","2017"],axis=1)
personal_consumption_final = personal_consumption_final.drop(["2018","2019","2020","2021"],axis=1)
personal_consumption_final.head()
# Out:
#    State Name  personal_consumption_2015  personal_consumption_2016  \
# 0     Alabama                    12471.7                    12741.1
# 1      Alaska                     2773.3                     2721.7
# 2     Arizona                    18537.3                    19046.5
# 3    Arkansas                     7206.8                     7445.5
# 4  California                   113368.8                   116078.5
#
#    personal_consumption_2017  personal_consumption_2018  \
# 0                    13003.7                    13425.9
# 1                     2707.8                     2741.0
# 2                    20009.6                    20494.1
# 3                     7595.0                     7678.9
# 4                   119796.3                   123086.1
#
#    personal_consumption_2019  personal_consumption_2020  \
# 0                    13851.2                    15107.6
# 1                     2778.2                     2902.5
# ...

# %%
#Final data set with personal consumption data of all the states in required years
personal_consumption_final.head()
# Out:
#    State Name  personal_consumption_2015  personal_consumption_2016  \
# 0     Alabama                    12471.7                    12741.1
# 1      Alaska                     2773.3                     2721.7
# 2     Arizona                    18537.3                    19046.5
# 3    Arkansas                     7206.8                     7445.5
# 4  California                   113368.8                   116078.5
#
#    personal_consumption_2017  personal_consumption_2018  \
# 0                    13003.7                    13425.9
# 1                     2707.8                     2741.0
# 2                    20009.6                    20494.1
# 3                     7595.0                     7678.9
# 4                   119796.3                   123086.1
#
#    personal_consumption_2019  personal_consumption_2020  \
# 0                    13851.2                    15107.6
# 1                     2778.2                     2902.5
# ...

# %%
#ALL MY FINAL DATA SETS

# %%
population_final.head()
# Out:
#    State Name  pop_2015  pop_2016  pop_2017  pop_2018  pop_2019  pop_2020  \
# 0     Alabama   4858979   4863300   4874747   4887871   4903185   5024803
# 1      Alaska    738432    741894    739795    737438    731545    732441
# 2     Arizona   6828065   6931071   7016270   7171646   7278717   7177986
# 3    Arkansas   2978204   2988248   3004279   3013825   3017804   3012232
# 4  California  39144818  39250017  39536653  39557045  39512223  39499738
#
#    pop_2021
# 0   5039877
# 1    732673
# 2   7276316
# 3   3025891
# 4  39237836

# %%
GDP_final.head()
# Out:
#    State Name   GDP_2015   GDP_2016    GDP_2017    GDP_2018    GDP_2019  \
# 0     Alabama   765340.9   777135.2    787899.6    801490.5    813730.8
# 1      Alaska   218963.4   216986.5    217114.7    213307.9    213735.2
# 2     Arizona  1130307.9  1165100.9   1214424.2   1259309.7   1301581.1
# 3    Arkansas   449403.9   451192.5    455401.0    463540.9    468504.7
# 4  California  9429811.7  9711578.3  10152816.2  10576244.7  10916903.3
#
#      GDP_2020    GDP_2021
# 0    799523.1    839917.2
# 1    202820.7    203477.6
# 2   1308712.1   1390623.9
# 3    469072.6    493389.3
# 4  10668883.7  11498923.2

# %%
Revenue_final.head()
# Out:
#   Fastfood_chain  Revenue_2015  Revenue_2016  Revenue_2017  Revenue_2018  \
# 0         wendys       5760332       6947993       6505412       5004865
# 1      starbucks      75025500      61998100     111165500      97577500
# 2       chipotle      17808758      16065593      17325818      18824080
# 3      Mcdonalds     103772700     100039500      94902000      86331300
# 4        dominos       6240470       9176976      13173121      12724159
#
#    Revenue_2019  Revenue_2020  Revenue_2021
# 0       5317263       4070771       5872368
# 1     105099500      97412900      80020300
# 2      21174896      23110137      27899873
# 3      84340300      78991100      87112900
# 4      14168500      11331398      17056601

# %%
percapita_final.head()
# Out:
#    State Name  percapita_2015  percapita_2016  percapita_2017  percapita_2018  \
# 0     Alabama        0.039469        0.040181        0.040729        0.041182
# 1      Alaska        0.073861        0.072618        0.073209        0.072281
# 2     Arizona        0.041735        0.042495        0.043929        0.044232
# 3    Arkansas        0.037853        0.038060        0.038257        0.038670
# 4  California        0.060536        0.062591        0.065756        0.067619
#
#    percapita_2019  percapita_2020  percapita_2021
# 0        0.041701        0.040678        0.042269
# 1        0.073250        0.069725        0.069804
# 2        0.045435        0.047114        0.049108
# 3        0.039152        0.039735        0.041256
# 4        0.070172        0.069527        0.075003

# %%
personal_consumption_final.head()
# Out:
#    State Name  personal_consumption_2015  personal_consumption_2016  \
# 0     Alabama                    12471.7                    12741.1
# 1      Alaska                     2773.3                     2721.7
# 2     Arizona                    18537.3                    19046.5
# 3    Arkansas                     7206.8                     7445.5
# 4  California                   113368.8                   116078.5
#
#    personal_consumption_2017  personal_consumption_2018  \
# 0                    13003.7                    13425.9
# 1                     2707.8                     2741.0
# 2                    20009.6                    20494.1
# 3                     7595.0                     7678.9
# 4                   119796.3                   123086.1
#
#    personal_consumption_2019  personal_consumption_2020  \
# 0                    13851.2                    15107.6
# 1                     2778.2                     2902.5
# ...

# %%
#concatenation of all the final data sets into one dataframe based on state name
import functools as ft
tables = [population_final, GDP_final, percapita_final, personal_consumption_final]

final_data = ft.reduce(lambda left, right: pd.merge(left, right,how='left', on='State Name'),tables)

# %%
final_data
# Out:
#         State Name  pop_2015  pop_2016  pop_2017  pop_2018  pop_2019  \
# 0          Alabama   4858979   4863300   4874747   4887871   4903185
# 1           Alaska    738432    741894    739795    737438    731545
# 2          Arizona   6828065   6931071   7016270   7171646   7278717
# 3         Arkansas   2978204   2988248   3004279   3013825   3017804
# 4       California  39144818  39250017  39536653  39557045  39512223
# 5         Colorado   5456574   5540545   5607154   5695564   5758736
# 6      Connecticut   3590886   3576452   3588184   3572665   3565287
# 7         Delaware    945934    952065    961939    967171    973764
# 8          Florida  20271272  20612439  20984400  21299325  21477737
# 9          Georgia  10214860  10310371  10429379  10519475  10617423
# 10          Hawaii   1431603   1428557   1427538   1420491   1415872
# 11           Idaho   1654930   1683140   1716943   1754208   1787065
# 12        Illinois  12859995  12801539  12802023  12741080  12671821
# ...

# %%
#Exporting all our final datasets into csv files
population_final.to_csv("population_final")
GDP_final.to_csv("GDP_final")
percapita_final.to_csv("percapita_income_final")
personal_consumption_final.to_csv("personal_consumption_final")

# %%
Revenue_final.to_csv("Revenue_final")

# %%
final_data.to_csv("final_data")
